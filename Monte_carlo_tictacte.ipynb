# %%
import math
import numpy as np

# %%
#reference to the formula in which the first part wi/ni will be the expansion 
#the sqrt(c*log(N)/ni) is the exploration
def ucb_score(parent,child):
  if(parent.visit_count==0) or child.visit_count==0:
    return 100
  return child.value()+math.sqrt(5*math.log(parent.visit_count)/(child.visit_count+1))

# %%
#class for a node in monte carlo search tree
class Node:
  def __init__(self, state, to_play):
    self.visit_count = 0
    #number of times a node is visited
    self.to_play = to_play
    self.win_count = 0
    #number of wins
    self.children = {}
    #stoore all the children connected
    self.state = ""
  
  def value(self):
    if(self.visit_count==0):
      return 0
    return self.win_count/self.visit_count
  
  def select_child(self):
    #selecting the best action based on ucb score
    best_score = -np.inf 
    best_action = None 
    best_child = None 

    for action,child in self.children.items():
      score=ucb_score(self,child)
      if score>best_score:
        best_score=score 
        best_action=action
        best_child=child 
    
    return best_action,best_child

# %%
#TicTacToe Board
class Board:
  def __init__(self):
    #board is designed
    self.board = np.zeros(9)
    self.end = False 
    #player
    self.player_to_play=1 

  def winner(self):
    #finds the winner 
    if np.sum(self.board[0:3])==3 or np.sum(self.board[3:6])==3 or np.sum(self.board[6:9])==3:
      self.end=True
      return 1
    if np.sum(self.board[0:3])==-3 or np.sum(self.board[3:6])==-3 or np.sum(self.board[6:9])==-3: 
      self.end=True 
      return -1

    if (self.board[0]+self.board[3]+self.board[6]==3 or self.board[1]+self.board[4]+self.board[7]==3 or self.board[2]+self.board[5]+self.board[8]==3) :
      self.end=True 
      return 1
    
    if (self.board[0]+self.board[3]+self.board[6]==-3 or self.board[1]+self.board[4]+self.board[7]==-3 or self.board[2]+self.board[5]+self.board[8]==-3) :
      self.end=True 
      return -1

    if (self.board[0]+self.board[4]+self.board[8]==3 or self.board[6]+self.board[4]+self.board[2]==3) :
      self.end=True 
      return 1

    if (self.board[0]+self.board[4]+self.board[8]==-3 or self.board[6]+self.board[4]+self.board[2]==-3) :
      self.end=True 
      return -1
    #checks draw
    if np.count_nonzero(self.board) == 9:
      self.end=True
      return 0

    self.end=False 
    return None
  
  def addposition(self,position):
    #add position to the board
    self.board[position]=self.player_to_play
    self.player_to_play*=-1


  def reset(self):
    #reset board
    self.board = np.zeros(9)
    self.end=False
    self.player_to_play=1 

  def legal_moves(self):
    #generate legal moves from the boardd
    positions=[]
    for i in range(9):
      if self.board[i]==0:
        positions.append(i)
    return positions

  def printboard(self):
    #printing board
    for i in range(9):
      if i%3==0 :
        print()
      ch='_'
      if self.board[i]==1:
        ch='X'
      if self.board[i]==-1:
        ch='O'
      print(ch,end=' ')

# %%
class Monte_Carlo_Tree_Search:
  #training based on running on different games
  def train(self,number_of_games,to_play):
    root=Node(None,to_play)
    #generate random moves and simulate the tree based on the criteria
    for i in range(number_of_games):
      node=root
      back_list=[]

      board=Board()
      val=to_play
      while board.winner() is  None:
        if val==1:
          if len(node.children)==0:
            for x in board.legal_moves():
              node.children[x]=Node(board,val*-1)
          bestaction,bestchild = node.select_child()

          back_list.append(bestchild)
          board.addposition(bestaction)
        else:
          if len(node.children)==0:
            for x in board.legal_moves():
              node.children[x]=Node(board,val*-1)
          bestaction,bestchild = node.select_child()
          back_list.append(bestchild)
          board.addposition(bestaction)
        node=bestchild
        val*=-1


      if board.winner()==1:
        print("Game ",i+1," is done,winner=player1")
      else:
        if board.winner()==0:
          print("Game ",i+1," is done,Draw")
        else:
          print("Game ",i+1," is done,winner=player2")
      self.backpropogate(back_list,1,val)
      root.visit_count+=1

    return root

  #backpropogate through the list
  def backpropogate(self,search_path,value,to_play):
    for node in reversed(search_path):
      node.win_count += value if node.to_play==to_play else 0
      node.visit_count+=1

# %%
mcst=Monte_Carlo_Tree_Search()
#training for more iteration the better it will learn
tree=mcst.train(number_of_games=3000000,to_play=1)
# Out:
# Streaming output truncated to the last 5000 lines.
# Game  995001  is done,winner=player1
# Game  995002  is done,winner=player1
# Game  995003  is done,winner=player1
# Game  995004  is done,winner=player1
# Game  995005  is done,winner=player1
# Game  995006  is done,winner=player1
# Game  995007  is done,winner=player1
# Game  995008  is done,Draw
# Game  995009  is done,Draw
# Game  995010  is done,winner=player1
# Game  995011  is done,winner=player1
# Game  995012  is done,winner=player1
# Game  995013  is done,winner=player1
# Game  995014  is done,Draw
# Game  995015  is done,Draw
# Game  995016  is done,winner=player1
# Game  995017  is done,winner=player1
# Game  995018  is done,Draw
# Game  995019  is done,winner=player1
# Game  995020  is done,winner=player1
# Game  995021  is done,winner=player1
# Game  995022  is done,winner=player1
# Game  995023  is done,winner=player1
# Game  995024  is done,winner=player1
# Game  995025  is done,winner=player1
# Game  995026  is done,winner=player1
# Game  995027  is done,winner=player1
# Game  995028  is done,winner=player1
# Game  995029  is done,winner=player1
# Game  995030  is done,winner=player1
# Game  995031  is done,winner=player1
# Game  995032  is done,winner=player1
# Game  995033  is done,winner=player1
# Game  995034  is done,Draw
# Game  995035  is done,Draw
# Game  995036  is done,winner=player1
# Game  995037  is done,winner=player1
# Game  995038  is done,winner=player1
# Game  995039  is done,Draw
# Game  995040  is done,winner=player1
# Game  995041  is done,Draw
# Game  995042  is done,winner=player1
# Game  995043  is done,winner=player1
# Game  995044  is done,winner=player1
# Game  995045  is done,winner=player1
# Game  995046  is done,winner=player1
# Game  995047  is done,winner=player1
# Game  995048  is done,winner=player1
# Game  995049  is done,winner=player1
# Game  995050  is done,winner=player1
# Game  995051  is done,winner=player1
# Game  995052  is done,winner=player1
# Game  995053  is done,winner=player1
# Game  995054  is done,Draw
# Game  995055  is done,winner=player1
# Game  995056  is done,winner=player1
# Game  995057  is done,winner=player1
# Game  995058  is done,winner=player1
# Game  995059  is done,winner=player1
# Game  995060  is done,winner=player1
# Game  995061  is done,winner=player1
# Game  995062  is done,winner=player1
# Game  995063  is done,winner=player1
# Game  995064  is done,winner=player1
# Game  995065  is done,winner=player1
# Game  995066  is done,Draw
# Game  995067  is done,winner=player1
# Game  995068  is done,Draw
# Game  995069  is done,winner=player1
# Game  995070  is done,winner=player1
# Game  995071  is done,winner=player1
# Game  995072  is done,winner=player1
# Game  995073  is done,winner=player1
# Game  995074  is done,winner=player1
# Game  995075  is done,winner=player1
# Game  995076  is done,winner=player1
# Game  995077  is done,winner=player1
# Game  995078  is done,winner=player1
# Game  995079  is done,winner=player1
# Game  995080  is done,winner=player1
# Game  995081  is done,winner=player1
# Game  995082  is done,winner=player1
# Game  995083  is done,winner=player1
# Game  995084  is done,winner=player1
# Game  995085  is done,winner=player1
# Game  995086  is done,Draw
# Game  995087  is done,winner=player1
# Game  995088  is done,winner=player1
# Game  995089  is done,Draw
# Game  995090  is done,winner=player1
# Game  995091  is done,winner=player1
# Game  995092  is done,winner=player1
# Game  995093  is done,winner=player1
# Game  995094  is done,winner=player1
# Game  995095  is done,winner=player1
# Game  995096  is done,winner=player1
# Game  995097  is done,winner=player1
# Game  995098  is done,winner=player1
# Game  995099  is done,winner=player1
# Game  995100  is done,winner=player1
# Game  995101  is done,winner=player1
# Game  995102  is done,winner=player1
# Game  995103  is done,winner=player1
# Game  995104  is done,winner=player1
# Game  995105  is done,winner=player1
# Game  995106  is done,winner=player1
# Game  995107  is done,winner=player1
# Game  995108  is done,Draw
# Game  995109  is done,Draw
# Game  995110  is done,winner=player1
# Game  995111  is done,winner=player1
# Game  995112  is done,winner=player1
# Game  995113  is done,winner=player1
# Game  995114  is done,winner=player1
# Game  995115  is done,winner=player1
# Game  995116  is done,winner=player1
# Game  995117  is done,winner=player1
# Game  995118  is done,winner=player1
# Game  995119  is done,winner=player1
# Game  995120  is done,Draw
# Game  995121  is done,winner=player1
# Game  995122  is done,winner=player1
# Game  995123  is done,winner=player1
# Game  995124  is done,winner=player1
# Game  995125  is done,winner=player1
# Game  995126  is done,winner=player1
# Game  995127  is done,winner=player1
# Game  995128  is done,winner=player1
# Game  995129  is done,winner=player1
# Game  995130  is done,winner=player1
# Game  995131  is done,Draw
# Game  995132  is done,Draw
# Game  995133  is done,winner=player1
# Game  995134  is done,winner=player1
# Game  995135  is done,winner=player1
# Game  995136  is done,winner=player1
# Game  995137  is done,winner=player1
# Game  995138  is done,winner=player1
# Game  995139  is done,winner=player1
# Game  995140  is done,winner=player1
# Game  995141  is done,winner=player1
# Game  995142  is done,winner=player1
# Game  995143  is done,Draw
# Game  995144  is done,winner=player1
# Game  995145  is done,winner=player1
# Game  995146  is done,winner=player1
# Game  995147  is done,winner=player1
# Game  995148  is done,winner=player1
# Game  995149  is done,winner=player1
# Game  995150  is done,winner=player1
# Game  995151  is done,winner=player1
# Game  995152  is done,winner=player1
# Game  995153  is done,winner=player1
# Game  995154  is done,winner=player1
# Game  995155  is done,winner=player1
# Game  995156  is done,winner=player1
# Game  995157  is done,winner=player1
# Game  995158  is done,winner=player1
# Game  995159  is done,winner=player1
# Game  995160  is done,winner=player1
# Game  995161  is done,winner=player1
# Game  995162  is done,winner=player1
# Game  995163  is done,winner=player1
# Game  995164  is done,winner=player1
# Game  995165  is done,Draw
# Game  995166  is done,winner=player1
# Game  995167  is done,winner=player1
# Game  995168  is done,winner=player1
# Game  995169  is done,winner=player1
# Game  995170  is done,Draw
# Game  995171  is done,winner=player1
# Game  995172  is done,winner=player1
# Game  995173  is done,winner=player1
# Game  995174  is done,winner=player1
# Game  995175  is done,winner=player1
# Game  995176  is done,winner=player1
# Game  995177  is done,winner=player1
# Game  995178  is done,winner=player1
# Game  995179  is done,winner=player1
# Game  995180  is done,winner=player1
# Game  995181  is done,winner=player1
# Game  995182  is done,winner=player1
# Game  995183  is done,winner=player2
# Game  995184  is done,winner=player2
# Game  995185  is done,winner=player1
# Game  995186  is done,winner=player1
# Game  995187  is done,winner=player1
# Game  995188  is done,winner=player1
# Game  995189  is done,winner=player1
# Game  995190  is done,winner=player1
# Game  995191  is done,winner=player1
# Game  995192  is done,winner=player1
# Game  995193  is done,winner=player1
# Game  995194  is done,winner=player1
# Game  995195  is done,winner=player1
# Game  995196  is done,winner=player1
# Game  995197  is done,winner=player1
# Game  995198  is done,winner=player1
# Game  995199  is done,winner=player1
# Game  995200  is done,Draw
# Game  995201  is done,winner=player1
# Game  995202  is done,winner=player1
# Game  995203  is done,winner=player1
# Game  995204  is done,winner=player2
# Game  995205  is done,winner=player2
# Game  995206  is done,winner=player1
# Game  995207  is done,winner=player1
# Game  995208  is done,winner=player1
# Game  995209  is done,winner=player1
# Game  995210  is done,winner=player1
# Game  995211  is done,winner=player1
# Game  995212  is done,winner=player1
# Game  995213  is done,winner=player1
# Game  995214  is done,winner=player1
# Game  995215  is done,winner=player1
# Game  995216  is done,winner=player1
# Game  995217  is done,winner=player1
# Game  995218  is done,winner=player1
# Game  995219  is done,winner=player1
# Game  995220  is done,Draw
# Game  995221  is done,winner=player1
# Game  995222  is done,winner=player1
# Game  995223  is done,winner=player1
# Game  995224  is done,winner=player1
# Game  995225  is done,winner=player1
# Game  995226  is done,winner=player1
# Game  995227  is done,winner=player1
# Game  995228  is done,winner=player1
# Game  995229  is done,winner=player1
# Game  995230  is done,winner=player1
# Game  995231  is done,winner=player1
# Game  995232  is done,winner=player1
# Game  995233  is done,winner=player1
# Game  995234  is done,winner=player1
# Game  995235  is done,winner=player1
# Game  995236  is done,winner=player1
# Game  995237  is done,winner=player1
# Game  995238  is done,winner=player1
# Game  995239  is done,winner=player1
# Game  995240  is done,winner=player1
# Game  995241  is done,winner=player1
# Game  995242  is done,winner=player1
# Game  995243  is done,winner=player1
# Game  995244  is done,winner=player1
# Game  995245  is done,Draw
# Game  995246  is done,Draw
# Game  995247  is done,winner=player1
# Game  995248  is done,Draw
# Game  995249  is done,winner=player1
# Game  995250  is done,winner=player1
# Game  995251  is done,winner=player1
# Game  995252  is done,winner=player1
# Game  995253  is done,winner=player1
# Game  995254  is done,winner=player1
# Game  995255  is done,winner=player1
# Game  995256  is done,winner=player1
# Game  995257  is done,winner=player1
# Game  995258  is done,winner=player1
# Game  995259  is done,winner=player1
# Game  995260  is done,winner=player1
# Game  995261  is done,winner=player1
# Game  995262  is done,winner=player1
# Game  995263  is done,winner=player1
# Game  995264  is done,winner=player1
# Game  995265  is done,winner=player1
# Game  995266  is done,Draw
# Game  995267  is done,Draw
# Game  995268  is done,winner=player1
# Game  995269  is done,winner=player1
# Game  995270  is done,winner=player1
# Game  995271  is done,winner=player1
# Game  995272  is done,winner=player1
# Game  995273  is done,winner=player1
# Game  995274  is done,winner=player1
# Game  995275  is done,winner=player1
# Game  995276  is done,winner=player1
# Game  995277  is done,winner=player1
# Game  995278  is done,winner=player1
# Game  995279  is done,winner=player1
# Game  995280  is done,winner=player1
# Game  995281  is done,winner=player1
# Game  995282  is done,winner=player1
# Game  995283  is done,winner=player1
# Game  995284  is done,winner=player1
# Game  995285  is done,winner=player1
# Game  995286  is done,Draw
# Game  995287  is done,Draw
# Game  995288  is done,winner=player1
# Game  995289  is done,winner=player1
# Game  995290  is done,winner=player1
# Game  995291  is done,Draw
# Game  995292  is done,winner=player1
# Game  995293  is done,winner=player1
# Game  995294  is done,Draw
# Game  995295  is done,winner=player1
# Game  995296  is done,winner=player1
# Game  995297  is done,winner=player1
# Game  995298  is done,winner=player1
# Game  995299  is done,winner=player1
# Game  995300  is done,winner=player1
# Game  995301  is done,winner=player1
# Game  995302  is done,winner=player1
# Game  995303  is done,winner=player1
# Game  995304  is done,winner=player1
# Game  995305  is done,winner=player1
# Game  995306  is done,winner=player1
# Game  995307  is done,winner=player1
# Game  995308  is done,winner=player1
# Game  995309  is done,winner=player1
# Game  995310  is done,winner=player2
# Game  995311  is done,winner=player1
# Game  995312  is done,winner=player1
# Game  995313  is done,winner=player2
# Game  995314  is done,winner=player1
# Game  995315  is done,winner=player1
# Game  995316  is done,winner=player1
# Game  995317  is done,winner=player1
# Game  995318  is done,Draw
# Game  995319  is done,winner=player1
# Game  995320  is done,winner=player1
# Game  995321  is done,winner=player1
# Game  995322  is done,winner=player1
# Game  995323  is done,winner=player1
# Game  995324  is done,winner=player1
# Game  995325  is done,winner=player1
# Game  995326  is done,winner=player1
# Game  995327  is done,winner=player1
# Game  995328  is done,winner=player1
# Game  995329  is done,winner=player1
# Game  995330  is done,winner=player1
# Game  995331  is done,winner=player1
# Game  995332  is done,winner=player1
# Game  995333  is done,winner=player1
# Game  995334  is done,winner=player1
# Game  995335  is done,winner=player1
# Game  995336  is done,Draw
# Game  995337  is done,winner=player1
# Game  995338  is done,winner=player1
# Game  995339  is done,winner=player1
# Game  995340  is done,winner=player1
# Game  995341  is done,winner=player1
# Game  995342  is done,Draw
# Game  995343  is done,winner=player1
# Game  995344  is done,winner=player1
# Game  995345  is done,winner=player1
# Game  995346  is done,Draw
# Game  995347  is done,winner=player1
# Game  995348  is done,winner=player1
# Game  995349  is done,winner=player1
# Game  995350  is done,winner=player1
# Game  995351  is done,winner=player1
# Game  995352  is done,Draw
# Game  995353  is done,winner=player1
# Game  995354  is done,winner=player1
# Game  995355  is done,winner=player1
# Game  995356  is done,winner=player1
# Game  995357  is done,winner=player1
# Game  995358  is done,winner=player1
# Game  995359  is done,winner=player1
# Game  995360  is done,winner=player1
# Game  995361  is done,winner=player1
# Game  995362  is done,winner=player1
# Game  995363  is done,winner=player2
# Game  995364  is done,winner=player2
# Game  995365  is done,winner=player2
# Game  995366  is done,winner=player2
# Game  995367  is done,winner=player2
# Game  995368  is done,Draw
# Game  995369  is done,Draw
# Game  995370  is done,Draw
# Game  995371  is done,winner=player1
# Game  995372  is done,winner=player1
# Game  995373  is done,winner=player1
# Game  995374  is done,winner=player1
# Game  995375  is done,winner=player1
# Game  995376  is done,winner=player1
# Game  995377  is done,Draw
# Game  995378  is done,winner=player1
# Game  995379  is done,winner=player1
# Game  995380  is done,winner=player2
# Game  995381  is done,winner=player1
# Game  995382  is done,winner=player1
# Game  995383  is done,winner=player1
# Game  995384  is done,winner=player1
# Game  995385  is done,winner=player1
# Game  995386  is done,winner=player1
# Game  995387  is done,Draw
# Game  995388  is done,winner=player1
# Game  995389  is done,Draw
# Game  995390  is done,winner=player1
# Game  995391  is done,Draw
# Game  995392  is done,winner=player1
# Game  995393  is done,winner=player1
# Game  995394  is done,winner=player1
# Game  995395  is done,Draw
# Game  995396  is done,winner=player1
# Game  995397  is done,Draw
# Game  995398  is done,winner=player1
# Game  995399  is done,winner=player1
# Game  995400  is done,winner=player1
# Game  995401  is done,winner=player2
# Game  995402  is done,winner=player1
# Game  995403  is done,winner=player1
# Game  995404  is done,winner=player1
# Game  995405  is done,winner=player1
# Game  995406  is done,winner=player1
# Game  995407  is done,winner=player1
# Game  995408  is done,winner=player1
# Game  995409  is done,winner=player1
# Game  995410  is done,winner=player1
# Game  995411  is done,winner=player1
# Game  995412  is done,winner=player1
# Game  995413  is done,winner=player1
# Game  995414  is done,winner=player1
# Game  995415  is done,winner=player1
# Game  995416  is done,winner=player1
# Game  995417  is done,winner=player1
# Game  995418  is done,winner=player1
# Game  995419  is done,winner=player1
# Game  995420  is done,winner=player1
# Game  995421  is done,winner=player1
# Game  995422  is done,winner=player1
# Game  995423  is done,winner=player1
# Game  995424  is done,winner=player1
# Game  995425  is done,winner=player1
# Game  995426  is done,winner=player1
# Game  995427  is done,winner=player1
# Game  995428  is done,Draw
# Game  995429  is done,winner=player1
# Game  995430  is done,winner=player1
# Game  995431  is done,winner=player1
# Game  995432  is done,winner=player1
# Game  995433  is done,winner=player1
# Game  995434  is done,winner=player1
# Game  995435  is done,winner=player1
# Game  995436  is done,winner=player1
# Game  995437  is done,winner=player1
# Game  995438  is done,Draw
# Game  995439  is done,winner=player1
# Game  995440  is done,winner=player1
# Game  995441  is done,winner=player1
# Game  995442  is done,Draw
# Game  995443  is done,winner=player1
# Game  995444  is done,winner=player1
# Game  995445  is done,winner=player1
# Game  995446  is done,winner=player1
# Game  995447  is done,winner=player1
# Game  995448  is done,winner=player2
# Game  995449  is done,winner=player1
# Game  995450  is done,winner=player1
# Game  995451  is done,winner=player1
# Game  995452  is done,winner=player1
# Game  995453  is done,winner=player1
# Game  995454  is done,winner=player1
# Game  995455  is done,winner=player1
# Game  995456  is done,winner=player1
# Game  995457  is done,winner=player1
# Game  995458  is done,winner=player1
# Game  995459  is done,winner=player1
# Game  995460  is done,winner=player1
# Game  995461  is done,winner=player1
# Game  995462  is done,winner=player1
# Game  995463  is done,winner=player1
# Game  995464  is done,winner=player1
# Game  995465  is done,winner=player1
# Game  995466  is done,winner=player1
# Game  995467  is done,winner=player1
# Game  995468  is done,winner=player1
# Game  995469  is done,Draw
# Game  995470  is done,winner=player1
# Game  995471  is done,Draw
# Game  995472  is done,winner=player1
# Game  995473  is done,winner=player1
# Game  995474  is done,winner=player1
# Game  995475  is done,winner=player1
# Game  995476  is done,winner=player1
# Game  995477  is done,Draw
# Game  995478  is done,winner=player1
# Game  995479  is done,Draw
# Game  995480  is done,winner=player1
# Game  995481  is done,winner=player1
# Game  995482  is done,winner=player1
# Game  995483  is done,winner=player1
# Game  995484  is done,winner=player1
# Game  995485  is done,winner=player1
# Game  995486  is done,winner=player1
# Game  995487  is done,winner=player1
# Game  995488  is done,winner=player1
# Game  995489  is done,winner=player1
# Game  995490  is done,winner=player1
# Game  995491  is done,winner=player1
# Game  995492  is done,winner=player1
# Game  995493  is done,winner=player1
# Game  995494  is done,winner=player1
# Game  995495  is done,winner=player2
# Game  995496  is done,winner=player1
# Game  995497  is done,winner=player1
# Game  995498  is done,winner=player2
# Game  995499  is done,winner=player1
# Game  995500  is done,winner=player1
# Game  995501  is done,winner=player2
# Game  995502  is done,winner=player2
# Game  995503  is done,winner=player2
# Game  995504  is done,winner=player1
# Game  995505  is done,winner=player1
# Game  995506  is done,winner=player1
# Game  995507  is done,winner=player1
# Game  995508  is done,winner=player1
# Game  995509  is done,winner=player1
# Game  995510  is done,winner=player1
# Game  995511  is done,winner=player1
# Game  995512  is done,winner=player1
# Game  995513  is done,winner=player1
# Game  995514  is done,winner=player1
# Game  995515  is done,winner=player1
# Game  995516  is done,winner=player1
# Game  995517  is done,winner=player2
# Game  995518  is done,winner=player2
# Game  995519  is done,winner=player2
# Game  995520  is done,winner=player1
# Game  995521  is done,winner=player1
# Game  995522  is done,winner=player1
# Game  995523  is done,winner=player1
# Game  995524  is done,winner=player1
# Game  995525  is done,Draw
# Game  995526  is done,winner=player1
# Game  995527  is done,winner=player1
# Game  995528  is done,winner=player1
# Game  995529  is done,winner=player1
# Game  995530  is done,winner=player1
# Game  995531  is done,winner=player1
# Game  995532  is done,winner=player1
# Game  995533  is done,winner=player1
# Game  995534  is done,Draw
# Game  995535  is done,Draw
# Game  995536  is done,winner=player1
# Game  995537  is done,Draw
# Game  995538  is done,winner=player1
# Game  995539  is done,winner=player2
# Game  995540  is done,winner=player1
# Game  995541  is done,winner=player1
# Game  995542  is done,winner=player1
# Game  995543  is done,winner=player1
# Game  995544  is done,winner=player1
# Game  995545  is done,winner=player1
# Game  995546  is done,winner=player1
# Game  995547  is done,winner=player1
# Game  995548  is done,winner=player1
# Game  995549  is done,winner=player1
# Game  995550  is done,Draw
# Game  995551  is done,winner=player1
# Game  995552  is done,winner=player1
# Game  995553  is done,winner=player1
# Game  995554  is done,winner=player1
# Game  995555  is done,winner=player1
# Game  995556  is done,winner=player1
# Game  995557  is done,winner=player1
# Game  995558  is done,Draw
# Game  995559  is done,winner=player1
# Game  995560  is done,winner=player1
# Game  995561  is done,winner=player1
# Game  995562  is done,winner=player1
# Game  995563  is done,winner=player1
# Game  995564  is done,winner=player1
# Game  995565  is done,winner=player1
# Game  995566  is done,winner=player1
# Game  995567  is done,winner=player1
# Game  995568  is done,winner=player1
# Game  995569  is done,winner=player1
# Game  995570  is done,winner=player1
# Game  995571  is done,winner=player1
# Game  995572  is done,winner=player1
# Game  995573  is done,winner=player1
# Game  995574  is done,winner=player1
# Game  995575  is done,winner=player1
# Game  995576  is done,winner=player1
# Game  995577  is done,winner=player1
# Game  995578  is done,winner=player1
# Game  995579  is done,winner=player1
# Game  995580  is done,winner=player1
# Game  995581  is done,winner=player1
# Game  995582  is done,Draw
# Game  995583  is done,winner=player1
# Game  995584  is done,winner=player1
# Game  995585  is done,winner=player1
# Game  995586  is done,winner=player2
# Game  995587  is done,winner=player1
# Game  995588  is done,winner=player1
# Game  995589  is done,winner=player1
# Game  995590  is done,winner=player1
# Game  995591  is done,winner=player1
# Game  995592  is done,winner=player1
# Game  995593  is done,winner=player1
# Game  995594  is done,winner=player1
# Game  995595  is done,winner=player1
# Game  995596  is done,winner=player1
# Game  995597  is done,Draw
# Game  995598  is done,winner=player1
# Game  995599  is done,winner=player1
# Game  995600  is done,winner=player1
# Game  995601  is done,winner=player1
# Game  995602  is done,winner=player1
# Game  995603  is done,winner=player1
# Game  995604  is done,winner=player1
# Game  995605  is done,Draw
# Game  995606  is done,winner=player1
# Game  995607  is done,winner=player1
# Game  995608  is done,winner=player1
# Game  995609  is done,winner=player1
# Game  995610  is done,winner=player1
# Game  995611  is done,winner=player1
# Game  995612  is done,winner=player1
# Game  995613  is done,winner=player1
# Game  995614  is done,winner=player1
# Game  995615  is done,winner=player1
# Game  995616  is done,winner=player1
# Game  995617  is done,winner=player1
# Game  995618  is done,winner=player1
# Game  995619  is done,winner=player1
# Game  995620  is done,winner=player1
# Game  995621  is done,winner=player1
# Game  995622  is done,winner=player1
# Game  995623  is done,winner=player1
# Game  995624  is done,winner=player1
# Game  995625  is done,winner=player1
# Game  995626  is done,winner=player1
# Game  995627  is done,winner=player1
# Game  995628  is done,winner=player1
# Game  995629  is done,Draw
# Game  995630  is done,winner=player1
# Game  995631  is done,winner=player1
# Game  995632  is done,winner=player1
# Game  995633  is done,winner=player2
# Game  995634  is done,winner=player2
# Game  995635  is done,winner=player2
# Game  995636  is done,winner=player1
# Game  995637  is done,winner=player1
# Game  995638  is done,winner=player1
# Game  995639  is done,winner=player1
# Game  995640  is done,winner=player1
# Game  995641  is done,winner=player1
# Game  995642  is done,winner=player1
# Game  995643  is done,winner=player1
# Game  995644  is done,winner=player1
# Game  995645  is done,Draw
# Game  995646  is done,winner=player1
# Game  995647  is done,winner=player1
# Game  995648  is done,winner=player1
# Game  995649  is done,winner=player1
# Game  995650  is done,winner=player1
# Game  995651  is done,winner=player1
# Game  995652  is done,winner=player1
# Game  995653  is done,winner=player1
# Game  995654  is done,winner=player1
# Game  995655  is done,winner=player1
# Game  995656  is done,winner=player1
# Game  995657  is done,winner=player1
# Game  995658  is done,winner=player1
# Game  995659  is done,winner=player1
# Game  995660  is done,winner=player1
# Game  995661  is done,winner=player1
# Game  995662  is done,winner=player2
# Game  995663  is done,winner=player1
# Game  995664  is done,winner=player1
# Game  995665  is done,winner=player1
# Game  995666  is done,winner=player1
# Game  995667  is done,winner=player1
# Game  995668  is done,winner=player1
# Game  995669  is done,winner=player1
# Game  995670  is done,winner=player1
# Game  995671  is done,winner=player1
# Game  995672  is done,winner=player1
# Game  995673  is done,winner=player1
# Game  995674  is done,winner=player1
# Game  995675  is done,winner=player1
# Game  995676  is done,winner=player1
# Game  995677  is done,winner=player1
# Game  995678  is done,winner=player1
# Game  995679  is done,winner=player1
# Game  995680  is done,winner=player1
# Game  995681  is done,winner=player1
# Game  995682  is done,winner=player1
# Game  995683  is done,winner=player2
# Game  995684  is done,winner=player2
# Game  995685  is done,winner=player2
# Game  995686  is done,Draw
# Game  995687  is done,winner=player1
# Game  995688  is done,Draw
# Game  995689  is done,winner=player1
# Game  995690  is done,winner=player1
# Game  995691  is done,winner=player1
# Game  995692  is done,winner=player1
# Game  995693  is done,winner=player1
# Game  995694  is done,winner=player1
# Game  995695  is done,winner=player1
# Game  995696  is done,Draw
# Game  995697  is done,winner=player1
# Game  995698  is done,winner=player1
# Game  995699  is done,winner=player1
# Game  995700  is done,winner=player1
# Game  995701  is done,winner=player1
# Game  995702  is done,winner=player1
# Game  995703  is done,winner=player1
# Game  995704  is done,Draw
# Game  995705  is done,winner=player1
# Game  995706  is done,winner=player1
# Game  995707  is done,winner=player1
# Game  995708  is done,winner=player1
# Game  995709  is done,winner=player1
# Game  995710  is done,winner=player1
# Game  995711  is done,winner=player1
# Game  995712  is done,winner=player1
# Game  995713  is done,winner=player1
# Game  995714  is done,winner=player1
# Game  995715  is done,winner=player1
# Game  995716  is done,winner=player1
# Game  995717  is done,winner=player1
# Game  995718  is done,winner=player1
# Game  995719  is done,winner=player1
# Game  995720  is done,winner=player1
# Game  995721  is done,winner=player1
# Game  995722  is done,winner=player1
# Game  995723  is done,winner=player1
# Game  995724  is done,winner=player1
# Game  995725  is done,winner=player1
# Game  995726  is done,winner=player1
# Game  995727  is done,winner=player1
# Game  995728  is done,Draw
# Game  995729  is done,winner=player1
# Game  995730  is done,winner=player1
# Game  995731  is done,winner=player1
# Game  995732  is done,winner=player2
# Game  995733  is done,winner=player1
# Game  995734  is done,winner=player1
# Game  995735  is done,winner=player1
# Game  995736  is done,winner=player1
# Game  995737  is done,winner=player1
# Game  995738  is done,winner=player1
# Game  995739  is done,winner=player1
# Game  995740  is done,winner=player1
# Game  995741  is done,winner=player1
# Game  995742  is done,winner=player1
# Game  995743  is done,winner=player1
# Game  995744  is done,winner=player1
# Game  995745  is done,winner=player1
# Game  995746  is done,winner=player1
# Game  995747  is done,winner=player1
# Game  995748  is done,winner=player1
# Game  995749  is done,winner=player1
# Game  995750  is done,winner=player1
# Game  995751  is done,winner=player1
# Game  995752  is done,winner=player1
# Game  995753  is done,winner=player1
# Game  995754  is done,winner=player1
# Game  995755  is done,winner=player1
# Game  995756  is done,winner=player1
# Game  995757  is done,winner=player1
# Game  995758  is done,winner=player1
# Game  995759  is done,winner=player1
# Game  995760  is done,winner=player1
# Game  995761  is done,winner=player1
# Game  995762  is done,winner=player1
# Game  995763  is done,winner=player1
# Game  995764  is done,winner=player1
# Game  995765  is done,winner=player1
# Game  995766  is done,winner=player1
# Game  995767  is done,winner=player1
# Game  995768  is done,winner=player1
# Game  995769  is done,winner=player1
# Game  995770  is done,winner=player1
# Game  995771  is done,winner=player1
# Game  995772  is done,winner=player1
# Game  995773  is done,winner=player1
# Game  995774  is done,winner=player1
# Game  995775  is done,winner=player1
# Game  995776  is done,winner=player1
# Game  995777  is done,winner=player1
# Game  995778  is done,winner=player1
# Game  995779  is done,winner=player2
# Game  995780  is done,winner=player1
# Game  995781  is done,winner=player1
# Game  995782  is done,Draw
# Game  995783  is done,winner=player1
# Game  995784  is done,winner=player1
# Game  995785  is done,Draw
# Game  995786  is done,winner=player1
# Game  995787  is done,winner=player1
# Game  995788  is done,winner=player1
# Game  995789  is done,winner=player1
# Game  995790  is done,winner=player1
# Game  995791  is done,winner=player1
# Game  995792  is done,winner=player1
# Game  995793  is done,winner=player1
# Game  995794  is done,winner=player1
# Game  995795  is done,winner=player1
# Game  995796  is done,winner=player2
# Game  995797  is done,Draw
# Game  995798  is done,winner=player1
# Game  995799  is done,Draw
# Game  995800  is done,Draw
# Game  995801  is done,winner=player1
# Game  995802  is done,winner=player1
# Game  995803  is done,winner=player1
# Game  995804  is done,winner=player1
# Game  995805  is done,winner=player1
# Game  995806  is done,winner=player1
# Game  995807  is done,winner=player1
# Game  995808  is done,winner=player1
# Game  995809  is done,winner=player1
# Game  995810  is done,winner=player1
# Game  995811  is done,Draw
# Game  995812  is done,winner=player1
# Game  995813  is done,winner=player1
# Game  995814  is done,winner=player1
# Game  995815  is done,winner=player1
# Game  995816  is done,winner=player1
# Game  995817  is done,winner=player1
# Game  995818  is done,winner=player1
# Game  995819  is done,winner=player2
# Game  995820  is done,winner=player2
# Game  995821  is done,winner=player2
# Game  995822  is done,winner=player2
# Game  995823  is done,winner=player2
# Game  995824  is done,winner=player1
# Game  995825  is done,winner=player2
# Game  995826  is done,winner=player1
# Game  995827  is done,winner=player2
# Game  995828  is done,winner=player1
# Game  995829  is done,winner=player1
# Game  995830  is done,winner=player1
# Game  995831  is done,winner=player1
# Game  995832  is done,winner=player1
# Game  995833  is done,winner=player1
# Game  995834  is done,winner=player1
# Game  995835  is done,winner=player1
# Game  995836  is done,winner=player1
# Game  995837  is done,winner=player1
# Game  995838  is done,winner=player1
# Game  995839  is done,winner=player1
# Game  995840  is done,winner=player1
# Game  995841  is done,winner=player1
# Game  995842  is done,winner=player1
# Game  995843  is done,winner=player1
# Game  995844  is done,winner=player1
# Game  995845  is done,winner=player1
# Game  995846  is done,winner=player1
# Game  995847  is done,winner=player1
# Game  995848  is done,winner=player1
# Game  995849  is done,winner=player1
# Game  995850  is done,winner=player1
# Game  995851  is done,winner=player1
# Game  995852  is done,winner=player1
# Game  995853  is done,winner=player1
# Game  995854  is done,winner=player1
# Game  995855  is done,winner=player1
# Game  995856  is done,winner=player1
# Game  995857  is done,winner=player1
# Game  995858  is done,winner=player1
# Game  995859  is done,winner=player1
# Game  995860  is done,winner=player1
# Game  995861  is done,winner=player1
# Game  995862  is done,winner=player1
# Game  995863  is done,winner=player1
# Game  995864  is done,winner=player1
# Game  995865  is done,winner=player1
# Game  995866  is done,winner=player1
# Game  995867  is done,winner=player1
# Game  995868  is done,winner=player1
# Game  995869  is done,winner=player1
# Game  995870  is done,winner=player1
# Game  995871  is done,winner=player1
# Game  995872  is done,winner=player1
# Game  995873  is done,winner=player1
# Game  995874  is done,winner=player1
# Game  995875  is done,winner=player1
# Game  995876  is done,winner=player1
# Game  995877  is done,Draw
# Game  995878  is done,winner=player1
# Game  995879  is done,winner=player1
# Game  995880  is done,winner=player1
# Game  995881  is done,winner=player1
# Game  995882  is done,winner=player1
# Game  995883  is done,winner=player1
# Game  995884  is done,winner=player1
# Game  995885  is done,winner=player1
# Game  995886  is done,winner=player1
# Game  995887  is done,winner=player1
# Game  995888  is done,winner=player1
# Game  995889  is done,winner=player1
# Game  995890  is done,winner=player1
# Game  995891  is done,winner=player1
# Game  995892  is done,winner=player1
# Game  995893  is done,winner=player1
# Game  995894  is done,winner=player1
# Game  995895  is done,winner=player1
# Game  995896  is done,winner=player1
# Game  995897  is done,winner=player1
# Game  995898  is done,winner=player1
# Game  995899  is done,winner=player1
# Game  995900  is done,winner=player1
# Game  995901  is done,Draw
# Game  995902  is done,winner=player1
# Game  995903  is done,winner=player1
# Game  995904  is done,winner=player1
# Game  995905  is done,Draw
# Game  995906  is done,winner=player1
# Game  995907  is done,winner=player1
# Game  995908  is done,winner=player1
# Game  995909  is done,winner=player1
# Game  995910  is done,winner=player1
# Game  995911  is done,winner=player1
# Game  995912  is done,winner=player1
# Game  995913  is done,winner=player1
# Game  995914  is done,winner=player1
# Game  995915  is done,winner=player1
# Game  995916  is done,Draw
# Game  995917  is done,winner=player1
# Game  995918  is done,winner=player1
# Game  995919  is done,winner=player1
# Game  995920  is done,winner=player1
# Game  995921  is done,winner=player1
# Game  995922  is done,winner=player1
# Game  995923  is done,winner=player1
# Game  995924  is done,Draw
# Game  995925  is done,winner=player1
# Game  995926  is done,winner=player1
# Game  995927  is done,winner=player1
# Game  995928  is done,winner=player1
# Game  995929  is done,winner=player1
# Game  995930  is done,winner=player1
# Game  995931  is done,winner=player1
# Game  995932  is done,winner=player1
# Game  995933  is done,winner=player1
# Game  995934  is done,winner=player1
# Game  995935  is done,winner=player1
# Game  995936  is done,winner=player2
# Game  995937  is done,winner=player1
# Game  995938  is done,Draw
# Game  995939  is done,winner=player1
# Game  995940  is done,Draw
# Game  995941  is done,winner=player1
# Game  995942  is done,winner=player1
# Game  995943  is done,winner=player1
# Game  995944  is done,winner=player1
# Game  995945  is done,winner=player1
# Game  995946  is done,winner=player1
# Game  995947  is done,winner=player1
# Game  995948  is done,Draw
# Game  995949  is done,winner=player1
# Game  995950  is done,winner=player1
# Game  995951  is done,winner=player1
# Game  995952  is done,winner=player1
# Game  995953  is done,winner=player1
# Game  995954  is done,winner=player1
# Game  995955  is done,winner=player1
# Game  995956  is done,Draw
# Game  995957  is done,winner=player1
# Game  995958  is done,winner=player1
# Game  995959  is done,winner=player1
# Game  995960  is done,winner=player1
# Game  995961  is done,winner=player1
# Game  995962  is done,winner=player1
# Game  995963  is done,winner=player1
# Game  995964  is done,winner=player1
# Game  995965  is done,winner=player1
# Game  995966  is done,winner=player1
# Game  995967  is done,winner=player1
# Game  995968  is done,winner=player1
# Game  995969  is done,winner=player1
# Game  995970  is done,winner=player1
# Game  995971  is done,winner=player1
# Game  995972  is done,winner=player1
# Game  995973  is done,winner=player1
# Game  995974  is done,winner=player1
# Game  995975  is done,Draw
# Game  995976  is done,Draw
# Game  995977  is done,winner=player1
# Game  995978  is done,winner=player1
# Game  995979  is done,winner=player1
# Game  995980  is done,Draw
# Game  995981  is done,winner=player1
# Game  995982  is done,winner=player1
# Game  995983  is done,Draw
# Game  995984  is done,winner=player1
# Game  995985  is done,winner=player1
# Game  995986  is done,winner=player1
# Game  995987  is done,winner=player1
# Game  995988  is done,winner=player1
# Game  995989  is done,Draw
# Game  995990  is done,winner=player1
# Game  995991  is done,winner=player1
# Game  995992  is done,winner=player1
# Game  995993  is done,winner=player1
# Game  995994  is done,Draw
# Game  995995  is done,winner=player1
# Game  995996  is done,winner=player1
# Game  995997  is done,winner=player1
# Game  995998  is done,winner=player1
# Game  995999  is done,winner=player1
# Game  996000  is done,winner=player1
# Game  996001  is done,winner=player1
# Game  996002  is done,winner=player1
# Game  996003  is done,winner=player1
# Game  996004  is done,winner=player1
# Game  996005  is done,winner=player1
# Game  996006  is done,winner=player1
# Game  996007  is done,winner=player1
# Game  996008  is done,winner=player1
# Game  996009  is done,winner=player1
# Game  996010  is done,winner=player1
# Game  996011  is done,winner=player1
# Game  996012  is done,winner=player1
# Game  996013  is done,winner=player1
# Game  996014  is done,winner=player1
# Game  996015  is done,winner=player1
# Game  996016  is done,winner=player1
# Game  996017  is done,winner=player1
# Game  996018  is done,Draw
# Game  996019  is done,winner=player1
# Game  996020  is done,winner=player1
# Game  996021  is done,winner=player1
# Game  996022  is done,winner=player1
# Game  996023  is done,winner=player1
# Game  996024  is done,winner=player1
# Game  996025  is done,winner=player1
# Game  996026  is done,winner=player1
# Game  996027  is done,winner=player1
# Game  996028  is done,winner=player1
# Game  996029  is done,winner=player1
# Game  996030  is done,winner=player1
# Game  996031  is done,winner=player1
# Game  996032  is done,winner=player1
# Game  996033  is done,winner=player1
# Game  996034  is done,winner=player1
# Game  996035  is done,winner=player1
# Game  996036  is done,winner=player1
# Game  996037  is done,winner=player1
# Game  996038  is done,Draw
# Game  996039  is done,winner=player1
# Game  996040  is done,winner=player1
# Game  996041  is done,winner=player1
# Game  996042  is done,winner=player1
# Game  996043  is done,winner=player1
# Game  996044  is done,winner=player1
# Game  996045  is done,winner=player2
# Game  996046  is done,winner=player1
# Game  996047  is done,winner=player1
# Game  996048  is done,winner=player1
# Game  996049  is done,Draw
# Game  996050  is done,winner=player1
# Game  996051  is done,winner=player1
# Game  996052  is done,winner=player1
# Game  996053  is done,winner=player1
# Game  996054  is done,winner=player1
# Game  996055  is done,winner=player1
# Game  996056  is done,winner=player1
# Game  996057  is done,winner=player1
# Game  996058  is done,winner=player1
# Game  996059  is done,winner=player1
# Game  996060  is done,winner=player1
# Game  996061  is done,winner=player1
# Game  996062  is done,winner=player1
# Game  996063  is done,winner=player1
# Game  996064  is done,winner=player2
# Game  996065  is done,winner=player1
# Game  996066  is done,winner=player1
# Game  996067  is done,winner=player1
# Game  996068  is done,winner=player1
# Game  996069  is done,winner=player1
# Game  996070  is done,winner=player1
# Game  996071  is done,winner=player1
# Game  996072  is done,winner=player1
# Game  996073  is done,winner=player1
# Game  996074  is done,winner=player1
# Game  996075  is done,winner=player1
# Game  996076  is done,winner=player1
# Game  996077  is done,winner=player1
# Game  996078  is done,Draw
# Game  996079  is done,winner=player1
# Game  996080  is done,winner=player1
# Game  996081  is done,Draw
# Game  996082  is done,winner=player1
# Game  996083  is done,winner=player2
# Game  996084  is done,winner=player2
# Game  996085  is done,winner=player2
# Game  996086  is done,winner=player1
# Game  996087  is done,winner=player1
# Game  996088  is done,winner=player1
# Game  996089  is done,winner=player1
# Game  996090  is done,winner=player1
# Game  996091  is done,winner=player1
# Game  996092  is done,winner=player1
# Game  996093  is done,winner=player1
# Game  996094  is done,winner=player1
# Game  996095  is done,winner=player1
# Game  996096  is done,winner=player1
# Game  996097  is done,winner=player1
# Game  996098  is done,winner=player1
# Game  996099  is done,winner=player1
# Game  996100  is done,winner=player1
# Game  996101  is done,winner=player1
# Game  996102  is done,winner=player1
# Game  996103  is done,winner=player1
# Game  996104  is done,winner=player1
# Game  996105  is done,winner=player1
# Game  996106  is done,winner=player1
# Game  996107  is done,winner=player1
# Game  996108  is done,winner=player1
# Game  996109  is done,winner=player1
# Game  996110  is done,winner=player1
# Game  996111  is done,winner=player1
# Game  996112  is done,winner=player1
# Game  996113  is done,winner=player2
# Game  996114  is done,winner=player1
# Game  996115  is done,winner=player1
# Game  996116  is done,winner=player1
# Game  996117  is done,winner=player1
# Game  996118  is done,winner=player1
# Game  996119  is done,winner=player1
# Game  996120  is done,winner=player1
# Game  996121  is done,winner=player1
# Game  996122  is done,winner=player1
# Game  996123  is done,winner=player1
# Game  996124  is done,winner=player1
# Game  996125  is done,winner=player1
# Game  996126  is done,winner=player1
# Game  996127  is done,winner=player1
# Game  996128  is done,winner=player1
# Game  996129  is done,winner=player1
# Game  996130  is done,winner=player1
# Game  996131  is done,winner=player1
# Game  996132  is done,winner=player1
# Game  996133  is done,winner=player1
# Game  996134  is done,winner=player1
# Game  996135  is done,winner=player1
# Game  996136  is done,winner=player1
# Game  996137  is done,winner=player1
# Game  996138  is done,winner=player1
# Game  996139  is done,winner=player1
# Game  996140  is done,winner=player1
# Game  996141  is done,winner=player2
# Game  996142  is done,winner=player1
# Game  996143  is done,Draw
# Game  996144  is done,winner=player1
# Game  996145  is done,winner=player1
# Game  996146  is done,winner=player1
# Game  996147  is done,winner=player1
# Game  996148  is done,winner=player1
# Game  996149  is done,winner=player1
# Game  996150  is done,winner=player2
# Game  996151  is done,winner=player1
# Game  996152  is done,winner=player1
# Game  996153  is done,winner=player1
# Game  996154  is done,winner=player1
# Game  996155  is done,winner=player1
# Game  996156  is done,winner=player1
# Game  996157  is done,winner=player1
# Game  996158  is done,winner=player1
# Game  996159  is done,winner=player2
# Game  996160  is done,winner=player1
# Game  996161  is done,winner=player1
# Game  996162  is done,winner=player1
# Game  996163  is done,winner=player1
# Game  996164  is done,winner=player1
# Game  996165  is done,winner=player1
# Game  996166  is done,winner=player1
# Game  996167  is done,winner=player1
# Game  996168  is done,winner=player1
# Game  996169  is done,winner=player1
# Game  996170  is done,winner=player1
# Game  996171  is done,winner=player1
# Game  996172  is done,winner=player1
# Game  996173  is done,winner=player1
# Game  996174  is done,winner=player1
# Game  996175  is done,winner=player1
# Game  996176  is done,winner=player1
# Game  996177  is done,winner=player1
# Game  996178  is done,winner=player1
# Game  996179  is done,Draw
# Game  996180  is done,winner=player1
# Game  996181  is done,Draw
# Game  996182  is done,winner=player1
# Game  996183  is done,winner=player1
# Game  996184  is done,winner=player2
# Game  996185  is done,winner=player1
# Game  996186  is done,winner=player1
# Game  996187  is done,winner=player1
# Game  996188  is done,winner=player1
# Game  996189  is done,winner=player1
# Game  996190  is done,winner=player1
# Game  996191  is done,winner=player1
# Game  996192  is done,winner=player1
# Game  996193  is done,winner=player1
# Game  996194  is done,winner=player1
# Game  996195  is done,winner=player1
# Game  996196  is done,winner=player1
# Game  996197  is done,winner=player1
# Game  996198  is done,winner=player1
# Game  996199  is done,winner=player1
# Game  996200  is done,winner=player1
# Game  996201  is done,winner=player1
# Game  996202  is done,winner=player1
# Game  996203  is done,Draw
# Game  996204  is done,winner=player1
# Game  996205  is done,winner=player1
# Game  996206  is done,winner=player1
# Game  996207  is done,winner=player1
# Game  996208  is done,winner=player1
# Game  996209  is done,winner=player2
# Game  996210  is done,winner=player1
# Game  996211  is done,winner=player1
# Game  996212  is done,winner=player1
# Game  996213  is done,winner=player1
# Game  996214  is done,winner=player1
# Game  996215  is done,winner=player1
# Game  996216  is done,Draw
# Game  996217  is done,winner=player1
# Game  996218  is done,winner=player1
# Game  996219  is done,winner=player1
# Game  996220  is done,winner=player1
# Game  996221  is done,winner=player1
# Game  996222  is done,winner=player1
# Game  996223  is done,winner=player1
# Game  996224  is done,winner=player1
# Game  996225  is done,winner=player1
# Game  996226  is done,winner=player1
# Game  996227  is done,winner=player1
# Game  996228  is done,winner=player2
# Game  996229  is done,Draw
# Game  996230  is done,winner=player1
# Game  996231  is done,Draw
# Game  996232  is done,winner=player1
# Game  996233  is done,winner=player1
# Game  996234  is done,winner=player1
# Game  996235  is done,winner=player1
# Game  996236  is done,winner=player1
# Game  996237  is done,Draw
# Game  996238  is done,winner=player1
# Game  996239  is done,Draw
# Game  996240  is done,winner=player1
# Game  996241  is done,winner=player1
# Game  996242  is done,winner=player1
# Game  996243  is done,winner=player1
# Game  996244  is done,winner=player1
# Game  996245  is done,winner=player1
# Game  996246  is done,winner=player1
# Game  996247  is done,winner=player2
# Game  996248  is done,winner=player2
# Game  996249  is done,winner=player2
# Game  996250  is done,winner=player1
# Game  996251  is done,winner=player1
# Game  996252  is done,winner=player1
# Game  996253  is done,winner=player1
# Game  996254  is done,winner=player1
# Game  996255  is done,winner=player1
# Game  996256  is done,winner=player1
# Game  996257  is done,winner=player1
# Game  996258  is done,winner=player1
# Game  996259  is done,winner=player1
# Game  996260  is done,winner=player1
# Game  996261  is done,winner=player1
# Game  996262  is done,Draw
# Game  996263  is done,winner=player1
# Game  996264  is done,Draw
# Game  996265  is done,winner=player1
# Game  996266  is done,winner=player1
# Game  996267  is done,winner=player1
# Game  996268  is done,winner=player1
# Game  996269  is done,winner=player1
# Game  996270  is done,winner=player1
# Game  996271  is done,Draw
# Game  996272  is done,winner=player1
# Game  996273  is done,winner=player1
# Game  996274  is done,winner=player1
# Game  996275  is done,winner=player1
# Game  996276  is done,winner=player1
# Game  996277  is done,winner=player1
# Game  996278  is done,winner=player1
# Game  996279  is done,winner=player1
# Game  996280  is done,winner=player1
# Game  996281  is done,winner=player1
# Game  996282  is done,winner=player1
# Game  996283  is done,winner=player1
# Game  996284  is done,winner=player1
# Game  996285  is done,winner=player1
# Game  996286  is done,Draw
# Game  996287  is done,winner=player1
# Game  996288  is done,winner=player1
# Game  996289  is done,winner=player1
# Game  996290  is done,winner=player1
# Game  996291  is done,winner=player1
# Game  996292  is done,winner=player1
# Game  996293  is done,winner=player1
# Game  996294  is done,winner=player1
# Game  996295  is done,winner=player1
# Game  996296  is done,winner=player1
# Game  996297  is done,winner=player1
# Game  996298  is done,winner=player1
# Game  996299  is done,winner=player1
# Game  996300  is done,winner=player1
# Game  996301  is done,winner=player1
# Game  996302  is done,winner=player1
# Game  996303  is done,winner=player1
# Game  996304  is done,winner=player1
# Game  996305  is done,winner=player1
# Game  996306  is done,winner=player1
# Game  996307  is done,winner=player1
# Game  996308  is done,winner=player1
# Game  996309  is done,winner=player1
# Game  996310  is done,winner=player1
# Game  996311  is done,winner=player1
# Game  996312  is done,winner=player1
# Game  996313  is done,Draw
# Game  996314  is done,winner=player1
# Game  996315  is done,Draw
# Game  996316  is done,winner=player1
# Game  996317  is done,winner=player1
# Game  996318  is done,winner=player1
# Game  996319  is done,winner=player1
# Game  996320  is done,winner=player1
# Game  996321  is done,Draw
# Game  996322  is done,winner=player1
# Game  996323  is done,winner=player1
# Game  996324  is done,winner=player1
# Game  996325  is done,Draw
# Game  996326  is done,winner=player1
# ...
# Game  999555  is done,winner=player1
# Game  999556  is done,Draw
# Game  999557  is done,winner=player1
# Game  999558  is done,winner=player1
# Game  999559  is done,winner=player1
# Game  999560  is done,winner=player1
# Game  999561  is done,winner=player1
# Game  999562  is done,winner=player1
# Game  999563  is done,winner=player1
# Game  999564  is done,Draw
# Game  999565  is done,Draw
# Game  999566  is done,winner=player1
# Game  999567  is done,winner=player1
# Game  999568  is done,Draw
# Game  999569  is done,winner=player1
# Game  999570  is done,winner=player1
# Game  999571  is done,winner=player1
# Game  999572  is done,winner=player1
# Game  999573  is done,winner=player1
# Game  999574  is done,winner=player1
# Game  999575  is done,winner=player1
# Game  999576  is done,winner=player1
# Game  999577  is done,winner=player1
# Game  999578  is done,winner=player1
# Game  999579  is done,winner=player1
# Game  999580  is done,winner=player1
# Game  999581  is done,winner=player1
# Game  999582  is done,winner=player1
# Game  999583  is done,winner=player1
# Game  999584  is done,winner=player1
# Game  999585  is done,winner=player1
# Game  999586  is done,winner=player1
# Game  999587  is done,winner=player1
# Game  999588  is done,Draw
# Game  999589  is done,Draw
# Game  999590  is done,winner=player1
# Game  999591  is done,winner=player1
# Game  999592  is done,winner=player1
# Game  999593  is done,winner=player1
# Game  999594  is done,winner=player1
# Game  999595  is done,Draw
# Game  999596  is done,winner=player1
# Game  999597  is done,winner=player1
# Game  999598  is done,winner=player1
# Game  999599  is done,winner=player1
# Game  999600  is done,Draw
# Game  999601  is done,winner=player1
# Game  999602  is done,winner=player1
# Game  999603  is done,winner=player1
# Game  999604  is done,Draw
# Game  999605  is done,Draw
# Game  999606  is done,winner=player1
# Game  999607  is done,winner=player1
# Game  999608  is done,winner=player1
# Game  999609  is done,winner=player1
# Game  999610  is done,winner=player1
# Game  999611  is done,Draw
# Game  999612  is done,winner=player1
# Game  999613  is done,winner=player1
# Game  999614  is done,winner=player1
# Game  999615  is done,winner=player1
# Game  999616  is done,winner=player1
# Game  999617  is done,winner=player1
# Game  999618  is done,winner=player1
# Game  999619  is done,winner=player1
# Game  999620  is done,winner=player1
# Game  999621  is done,winner=player1
# Game  999622  is done,winner=player1
# Game  999623  is done,winner=player1
# Game  999624  is done,winner=player1
# Game  999625  is done,winner=player1
# Game  999626  is done,winner=player1
# Game  999627  is done,winner=player1
# Game  999628  is done,winner=player1
# Game  999629  is done,winner=player1
# Game  999630  is done,winner=player1
# Game  999631  is done,winner=player1
# Game  999632  is done,winner=player1
# Game  999633  is done,winner=player1
# Game  999634  is done,winner=player1
# Game  999635  is done,Draw
# Game  999636  is done,winner=player1
# Game  999637  is done,winner=player1
# Game  999638  is done,winner=player1
# Game  999639  is done,winner=player1
# Game  999640  is done,winner=player1
# Game  999641  is done,Draw
# Game  999642  is done,winner=player1
# Game  999643  is done,winner=player1
# Game  999644  is done,winner=player1
# Game  999645  is done,winner=player1
# Game  999646  is done,winner=player1
# Game  999647  is done,winner=player1
# Game  999648  is done,winner=player1
# Game  999649  is done,winner=player1
# Game  999650  is done,winner=player1
# Game  999651  is done,winner=player1
# Game  999652  is done,winner=player1
# Game  999653  is done,winner=player1
# Game  999654  is done,winner=player1
# Game  999655  is done,winner=player1
# Game  999656  is done,winner=player1
# Game  999657  is done,winner=player1
# Game  999658  is done,winner=player1
# Game  999659  is done,winner=player1
# Game  999660  is done,winner=player1
# Game  999661  is done,winner=player1
# Game  999662  is done,Draw
# Game  999663  is done,winner=player1
# Game  999664  is done,winner=player1
# Game  999665  is done,winner=player1
# Game  999666  is done,winner=player1
# Game  999667  is done,winner=player1
# Game  999668  is done,winner=player1
# Game  999669  is done,winner=player1
# Game  999670  is done,winner=player1
# Game  999671  is done,winner=player1
# Game  999672  is done,Draw
# Game  999673  is done,winner=player1
# Game  999674  is done,winner=player1
# Game  999675  is done,winner=player1
# Game  999676  is done,winner=player1
# Game  999677  is done,winner=player1
# Game  999678  is done,winner=player1
# Game  999679  is done,winner=player1
# Game  999680  is done,winner=player1
# Game  999681  is done,winner=player1
# Game  999682  is done,winner=player1
# Game  999683  is done,winner=player1
# Game  999684  is done,winner=player1
# Game  999685  is done,Draw
# Game  999686  is done,winner=player1
# Game  999687  is done,winner=player1
# Game  999688  is done,winner=player1
# Game  999689  is done,winner=player1
# Game  999690  is done,winner=player1
# Game  999691  is done,winner=player1
# Game  999692  is done,winner=player1
# Game  999693  is done,winner=player1
# Game  999694  is done,winner=player1
# Game  999695  is done,winner=player1
# Game  999696  is done,winner=player1
# Game  999697  is done,Draw
# Game  999698  is done,winner=player1
# Game  999699  is done,Draw
# Game  999700  is done,winner=player1
# Game  999701  is done,winner=player1
# Game  999702  is done,winner=player1
# Game  999703  is done,winner=player1
# Game  999704  is done,winner=player1
# Game  999705  is done,Draw
# Game  999706  is done,winner=player1
# Game  999707  is done,winner=player1
# Game  999708  is done,winner=player1
# Game  999709  is done,winner=player1
# Game  999710  is done,winner=player1
# Game  999711  is done,winner=player1
# Game  999712  is done,winner=player1
# Game  999713  is done,winner=player1
# Game  999714  is done,winner=player1
# Game  999715  is done,winner=player1
# Game  999716  is done,winner=player1
# Game  999717  is done,winner=player1
# Game  999718  is done,winner=player2
# Game  999719  is done,Draw
# Game  999720  is done,winner=player1
# Game  999721  is done,winner=player2
# Game  999722  is done,winner=player1
# Game  999723  is done,winner=player1
# Game  999724  is done,winner=player1
# Game  999725  is done,winner=player1
# Game  999726  is done,Draw
# Game  999727  is done,winner=player1
# Game  999728  is done,winner=player1
# Game  999729  is done,winner=player1
# Game  999730  is done,winner=player1
# Game  999731  is done,winner=player1
# Game  999732  is done,winner=player1
# Game  999733  is done,winner=player1
# Game  999734  is done,winner=player1
# Game  999735  is done,winner=player1
# Game  999736  is done,Draw
# Game  999737  is done,winner=player1
# Game  999738  is done,winner=player1
# Game  999739  is done,winner=player1
# Game  999740  is done,winner=player1
# Game  999741  is done,winner=player1
# Game  999742  is done,winner=player1
# Game  999743  is done,winner=player1
# Game  999744  is done,winner=player1
# Game  999745  is done,winner=player1
# Game  999746  is done,winner=player1
# Game  999747  is done,winner=player1
# Game  999748  is done,winner=player1
# Game  999749  is done,winner=player1
# Game  999750  is done,winner=player1
# Game  999751  is done,winner=player1
# Game  999752  is done,winner=player1
# Game  999753  is done,winner=player1
# Game  999754  is done,winner=player1
# Game  999755  is done,winner=player1
# Game  999756  is done,Draw
# Game  999757  is done,winner=player1
# Game  999758  is done,winner=player1
# Game  999759  is done,winner=player1
# Game  999760  is done,winner=player1
# Game  999761  is done,winner=player1
# Game  999762  is done,winner=player1
# Game  999763  is done,winner=player1
# Game  999764  is done,winner=player1
# Game  999765  is done,winner=player1
# Game  999766  is done,winner=player1
# Game  999767  is done,winner=player1
# Game  999768  is done,winner=player1
# Game  999769  is done,winner=player1
# Game  999770  is done,winner=player1
# Game  999771  is done,winner=player1
# Game  999772  is done,Draw
# Game  999773  is done,winner=player1
# Game  999774  is done,winner=player1
# Game  999775  is done,winner=player1
# Game  999776  is done,winner=player1
# Game  999777  is done,winner=player1
# Game  999778  is done,Draw
# Game  999779  is done,winner=player1
# Game  999780  is done,winner=player1
# Game  999781  is done,winner=player1
# Game  999782  is done,winner=player1
# Game  999783  is done,winner=player1
# Game  999784  is done,winner=player1
# Game  999785  is done,winner=player1
# Game  999786  is done,winner=player1
# Game  999787  is done,winner=player1
# Game  999788  is done,winner=player1
# Game  999789  is done,winner=player1
# Game  999790  is done,winner=player1
# Game  999791  is done,winner=player1
# Game  999792  is done,winner=player1
# Game  999793  is done,winner=player1
# Game  999794  is done,winner=player1
# Game  999795  is done,winner=player1
# Game  999796  is done,winner=player1
# Game  999797  is done,winner=player1
# Game  999798  is done,winner=player1
# Game  999799  is done,winner=player1
# Game  999800  is done,winner=player1
# Game  999801  is done,winner=player1
# Game  999802  is done,winner=player1
# Game  999803  is done,winner=player1
# Game  999804  is done,winner=player1
# Game  999805  is done,winner=player1
# Game  999806  is done,winner=player1
# Game  999807  is done,Draw
# Game  999808  is done,winner=player1
# Game  999809  is done,winner=player1
# Game  999810  is done,winner=player1
# Game  999811  is done,winner=player1
# Game  999812  is done,winner=player1
# Game  999813  is done,winner=player1
# Game  999814  is done,winner=player1
# Game  999815  is done,winner=player1
# Game  999816  is done,winner=player1
# Game  999817  is done,winner=player1
# Game  999818  is done,winner=player1
# Game  999819  is done,winner=player1
# Game  999820  is done,winner=player1
# Game  999821  is done,winner=player1
# Game  999822  is done,Draw
# Game  999823  is done,winner=player1
# Game  999824  is done,winner=player1
# Game  999825  is done,winner=player1
# Game  999826  is done,winner=player1
# Game  999827  is done,winner=player1
# Game  999828  is done,winner=player1
# Game  999829  is done,winner=player1
# Game  999830  is done,winner=player1
# Game  999831  is done,winner=player1
# Game  999832  is done,winner=player1
# Game  999833  is done,Draw
# Game  999834  is done,winner=player1
# Game  999835  is done,winner=player1
# Game  999836  is done,winner=player1
# Game  999837  is done,winner=player1
# Game  999838  is done,winner=player1
# Game  999839  is done,winner=player1
# Game  999840  is done,Draw
# Game  999841  is done,winner=player1
# Game  999842  is done,winner=player1
# Game  999843  is done,winner=player1
# Game  999844  is done,winner=player1
# Game  999845  is done,winner=player1
# Game  999846  is done,winner=player1
# Game  999847  is done,winner=player1
# Game  999848  is done,Draw
# Game  999849  is done,winner=player1
# Game  999850  is done,winner=player1
# Game  999851  is done,winner=player1
# Game  999852  is done,winner=player1
# Game  999853  is done,winner=player1
# Game  999854  is done,winner=player1
# Game  999855  is done,winner=player1
# Game  999856  is done,winner=player1
# Game  999857  is done,Draw
# Game  999858  is done,winner=player1
# Game  999859  is done,winner=player1
# Game  999860  is done,winner=player1
# Game  999861  is done,Draw
# Game  999862  is done,winner=player1
# Game  999863  is done,winner=player1
# Game  999864  is done,winner=player1
# Game  999865  is done,winner=player1
# Game  999866  is done,winner=player1
# Game  999867  is done,winner=player1
# Game  999868  is done,Draw
# Game  999869  is done,winner=player1
# Game  999870  is done,winner=player1
# Game  999871  is done,winner=player1
# Game  999872  is done,winner=player1
# Game  999873  is done,winner=player1
# Game  999874  is done,winner=player1
# Game  999875  is done,winner=player1
# Game  999876  is done,winner=player1
# Game  999877  is done,Draw
# Game  999878  is done,winner=player1
# Game  999879  is done,winner=player1
# Game  999880  is done,winner=player1
# Game  999881  is done,winner=player1
# Game  999882  is done,winner=player1
# Game  999883  is done,winner=player1
# Game  999884  is done,winner=player1
# Game  999885  is done,winner=player1
# Game  999886  is done,winner=player1
# Game  999887  is done,Draw
# Game  999888  is done,winner=player1
# Game  999889  is done,winner=player1
# Game  999890  is done,winner=player1
# Game  999891  is done,winner=player1
# Game  999892  is done,winner=player1
# Game  999893  is done,winner=player1
# Game  999894  is done,winner=player1
# Game  999895  is done,Draw
# Game  999896  is done,winner=player1
# Game  999897  is done,winner=player1
# Game  999898  is done,winner=player1
# Game  999899  is done,winner=player1
# Game  999900  is done,winner=player1
# Game  999901  is done,winner=player1
# Game  999902  is done,winner=player1
# Game  999903  is done,winner=player1
# Game  999904  is done,Draw
# Game  999905  is done,winner=player1
# Game  999906  is done,winner=player1
# Game  999907  is done,winner=player1
# Game  999908  is done,winner=player2
# Game  999909  is done,winner=player1
# Game  999910  is done,winner=player1
# Game  999911  is done,winner=player1
# Game  999912  is done,winner=player1
# Game  999913  is done,winner=player1
# Game  999914  is done,Draw
# Game  999915  is done,winner=player1
# Game  999916  is done,winner=player1
# Game  999917  is done,Draw
# Game  999918  is done,winner=player1
# Game  999919  is done,winner=player1
# Game  999920  is done,winner=player1
# Game  999921  is done,winner=player1
# Game  999922  is done,winner=player1
# Game  999923  is done,winner=player1
# Game  999924  is done,winner=player1
# Game  999925  is done,winner=player1
# Game  999926  is done,winner=player1
# Game  999927  is done,winner=player1
# Game  999928  is done,winner=player1
# Game  999929  is done,winner=player1
# Game  999930  is done,winner=player1
# Game  999931  is done,winner=player1
# Game  999932  is done,winner=player1
# Game  999933  is done,winner=player1
# Game  999934  is done,winner=player1
# Game  999935  is done,winner=player2
# Game  999936  is done,winner=player1
# Game  999937  is done,winner=player1
# Game  999938  is done,winner=player2
# Game  999939  is done,winner=player1
# Game  999940  is done,winner=player1
# Game  999941  is done,winner=player1
# Game  999942  is done,Draw
# Game  999943  is done,winner=player1
# Game  999944  is done,Draw
# Game  999945  is done,winner=player1
# Game  999946  is done,winner=player1
# Game  999947  is done,winner=player1
# Game  999948  is done,winner=player1
# Game  999949  is done,Draw
# Game  999950  is done,winner=player1
# Game  999951  is done,Draw
# Game  999952  is done,winner=player1
# Game  999953  is done,winner=player1
# Game  999954  is done,winner=player1
# Game  999955  is done,Draw
# Game  999956  is done,winner=player1
# Game  999957  is done,Draw
# Game  999958  is done,winner=player1
# Game  999959  is done,Draw
# Game  999960  is done,winner=player1
# Game  999961  is done,Draw
# Game  999962  is done,winner=player1
# Game  999963  is done,winner=player1
# Game  999964  is done,winner=player1
# Game  999965  is done,winner=player1
# Game  999966  is done,winner=player1
# Game  999967  is done,winner=player1
# Game  999968  is done,winner=player1
# Game  999969  is done,winner=player1
# Game  999970  is done,winner=player1
# Game  999971  is done,winner=player1
# Game  999972  is done,winner=player1
# Game  999973  is done,winner=player1
# Game  999974  is done,winner=player1
# Game  999975  is done,winner=player1
# Game  999976  is done,winner=player1
# Game  999977  is done,winner=player1
# Game  999978  is done,winner=player1
# Game  999979  is done,winner=player1
# Game  999980  is done,winner=player1
# Game  999981  is done,winner=player1
# Game  999982  is done,winner=player1
# Game  999983  is done,winner=player1
# Game  999984  is done,winner=player1
# Game  999985  is done,winner=player1
# Game  999986  is done,Draw
# Game  999987  is done,winner=player1
# Game  999988  is done,winner=player1
# Game  999989  is done,Draw
# Game  999990  is done,winner=player1
# Game  999991  is done,winner=player1
# Game  999992  is done,Draw
# Game  999993  is done,winner=player1
# Game  999994  is done,winner=player1
# Game  999995  is done,Draw
# Game  999996  is done,winner=player1
# Game  999997  is done,winner=player1
# Game  999998  is done,winner=player1
# Game  999999  is done,winner=player1
# Game  1000000  is done,winner=player1

# %%
def x_play_game(tree_node):
  #if x is played by mcts
  board=Board() 
  node=tree_node
  while board.winner() is  None:
    x = np.argmax([node.children[xx].value() for xx in node.children.keys()])
    
    print(x)
    actionlist=list(node.children.keys())

    board.addposition(actionlist[x])
    node=node.children[actionlist[x]]
    
    board.printboard() 
    
    if(board.winner() is not None):
      break
    print()
    while True:
      position=int(input("Enter position:"))
      if board.board[position]==0:
        break 
    board.addposition(position)
    
    node=node.children[position]
    
    board.printboard()
  if board.winner()==1:
    print("X Wins")
  else:
    if board.winner()==0:
      print("Draw")
    else:
      print("O wins")

# %%
def o_play_game(tree_node):
  #if o is play by mcts
  board=Board() 
  node=tree_node
  while board.winner() is  None:
    while True:
      position=int(input("Enter position:"))
      if board.board[position]==0:
        break 

    board.addposition(position)
    
    node=node.children[position]
    
    board.printboard()

    if(board.winner() is not None):
      break

    x = np.argmin([node.children[xx].value() for xx in node.children.keys()])
    actionlist=list(node.children.keys())


    board.addposition(actionlist[x])
    node=node.children[actionlist[x]]
    
    board.printboard() 
    
    
    print()
    
  if board.winner()==1:
    print("X Wins")
  else:
    if board.winner()==0:
      print("Draw")
    else:
      print("O wins")

# %%
x_play_game(tree)
# Out:
# 4
#
# _ _ _
# _ X _
# _ _ _
# Enter position:3
#
# _ _ _
# O X _
# _ _ _ 0
#
# X _ _
# O X _
# _ _ _
# Enter position:8
#
# X _ _
# O X _
# _ _ O 1
#
# X _ X
# O X _
# _ _ O
# Enter position:6
#
# X _ X
# O X _
# O _ O 0
#
# X X X
# O X _
# O _ O X Wins
